# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("train.csv")

# %%
data.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7693           FDB58       10.500              reg         0.013485
# 6313           FDX60       14.350          Low Fat         0.081050
# 4903           FDD34        7.945          Low Fat         0.015901
# 545            FDB38          NaN          Regular         0.000000
# 5671           NCX42          NaN          Low Fat         0.010468
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7693   Snack Foods  140.0154            OUT013                       1987
# 6313  Baking Goods   79.1960            OUT017                       2007
# 4903   Snack Foods  163.8210            OUT049                       1999
# 545         Canned  160.6920            OUT019                       1985
# 5671     Household  162.9526            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.isnull().sum() #gives the no of null values
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
percent_null=data.isnull().sum()*100/len(data)
print(percent_null)
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
data.duplicated().any()
# Out:
# False

# %%
data["Item_Weight"] #numerical column
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
data["Outlet_Size"] #categorical column
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
 mean_weight=data["Item_Weight"].mean()
 median_weight=data["Item_Weight"].median()

# %%
print(mean_weight)
print(median_weight)
# Out:
# 12.857645184135976
# 12.6

# %%
data["Item_Weight_mean"]=data["Item_Weight"].fillna(mean_weight)
data["Item_Weight_median"]=data["Item_Weight"].fillna(median_weight)

# %%
data.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0               Tier 1  Supermarket Type1           3735.138
#
#    Item_Weight_mean  Item_Weight_median
# 0               9.3                 9.3

# %%
data["Item_Weight"].plot(kind="kde",label="original data")
data["Item_Weight_mean"].plot(kind="kde",label="Mean")
data["Item_Weight_median"].plot(kind="kde",label="Median")
plt.legend()
plt.show()

# %%
data[["Item_Weight","Item_Weight_mean","Item_Weight_median"]].boxplot()
# Out:
# <Axes: >

# %%
data["Item_Weight_interpolate"]=data["Item_Weight"].interpolate(method="linear")

# %%
data["Item_Weight"].plot(kind="kde",label="original data")
data["Item_Weight_interpolate"].plot(kind="kde",label="interpolate")
plt.legend()
plt.show()
#it gives the nearest value compared to others as we have seen in graphs displayed

# %%
from sklearn.impute import KNNImputer

# %%
knn = KNNImputer(n_neighbors=10,weights="distance")

# %%
data["knn_imputer"] = knn.fit_transform(data[["Item_Weight"]]).ravel()

# %%
data["Item_Weight"].plot(kind="kde",label="original data")
data["knn_imputer"].plot(kind="kde",label="KNN")
plt.legend()
plt.show()

# %%
data = data.drop(["Item_Weight","Item_Weight_mean","Item_Weight_median","knn_imputer"],axis=1)

# %%
data.head(1)
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility Item_Type  Item_MRP  \
# 0           FDA15          Low Fat         0.016047     Dairy  249.8092
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0               Tier 1  Supermarket Type1           3735.138
#
#    Item_Weight_interpolate
# 0                      9.3

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Item_Weight_interpolate         0
# dtype: int64

# %%
#now fixing outlet_size

# %%
data["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
data["Outlet_Type"].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
mode_outlet=data.pivot_table(values="Outlet_Size",columns="Outlet_Type",aggfunc=(lambda x:x.mode()[0]))

# %%
mode_outlet
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
missing_values=data["Outlet_Size"].isnull()

# %%
missing_values
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
data.loc[missing_values,"Outlet_Size"]=data.loc[missing_values,"Outlet_Type"].apply(lambda x:mode_outlet[x])

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Item_Weight_interpolate      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales', 'Item_Weight_interpolate'],
#       dtype='object')

# %%
data["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
data.replace({"Item_Fat_Content":{"Low Fat":"LF","low fat": "LF","reg":"Regular"}},inplace=True)

# %%
data["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# LF         5517
# Regular    3006
# Name: count, dtype: int64

# %%
data["Item_Visibility"].value_counts()
# Out:
# Item_Visibility
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: count, Length: 7880, dtype: int64

# %%
data["Item_Visibility_interpolate"]=data["Item_Visibility"].replace(0,np.nan).interpolate(method="linear")

# %%
data.head(1)
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility Item_Type  Item_MRP  \
# 0           FDA15               LF         0.016047     Dairy  249.8092
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0               Tier 1  Supermarket Type1           3735.138
#
#    Item_Weight_interpolate  Item_Visibility_interpolate
# 0                      9.3                     0.016047

# %%
data["Item_Visibility_interpolate"].value_counts()
# Out:
# Item_Visibility_interpolate
# 0.076975    3
# 0.044024    2
# 0.040912    2
# 0.076856    2
# 0.078759    2
#            ..
# 0.021011    1
# 0.099189    1
# 0.076866    1
# 0.014116    1
# 0.044878    1
# Name: count, Length: 8405, dtype: int64

# %%
data["Item_Visibility_interpolate"].plot(kind="kde",label="interpolate",color="red")
data["Item_Visibility"].plot(kind="kde",label="Original")
plt.legend()
plt.show()

# %%
data=data.drop("Item_Visibility",axis=1)

# %%
data.head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type  Item_MRP  \
# 0           FDA15               LF                  Dairy  249.8092
# 1           DRC01          Regular            Soft Drinks   48.2692
# 2           FDN15               LF                   Meat  141.6180
# 3           FDX07          Regular  Fruits and Vegetables  182.0950
# 4           NCD19               LF              Household   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 3            OUT010                       1998       Small
# 4            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# ...

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Item_MRP',
#        'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales',
#        'Item_Weight_interpolate', 'Item_Visibility_interpolate'],
#       dtype='object')

# %%
data["Item_Type"].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
data["Item_Identifier"].value_counts().sample(5)
# Out:
# Item_Identifier
# FDO60    7
# FDT14    5
# FDT07    9
# DRI51    6
# FDX60    6
# Name: count, dtype: int64

# %%
data["Item_Identifier"]=data["Item_Identifier"].apply(lambda x: x[0:2])

# %%
data["Item_Identifier"].value_counts()
# Out:
# Item_Identifier
# FD    6125
# NC    1599
# DR     799
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Item_MRP',
#        'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales',
#        'Item_Weight_interpolate', 'Item_Visibility_interpolate'],
#       dtype='object')

# %%
data["Outlet_Establishment_Year"].value_counts()
# Out:
# Outlet_Establishment_Year
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: count, dtype: int64

# %%
import datetime as dt

# %%
current_year = dt.datetime.today().year

# %%
current_year
# Out:
# 2026

# %%
data["Age_Outlet"]=current_year-data["Outlet_Establishment_Year"]

# %%
data=data.drop("Outlet_Establishment_Year",axis=1)

# %%
data.head(5)
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type  Item_MRP  \
# 0              FD               LF                  Dairy  249.8092
# 1              DR          Regular            Soft Drinks   48.2692
# 2              FD               LF                   Meat  141.6180
# 3              FD          Regular  Fruits and Vegetables  182.0950
# 4              NC               LF              Household   53.8614
#
#   Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0            OUT049      Medium               Tier 1  Supermarket Type1
# 1            OUT018      Medium               Tier 3  Supermarket Type2
# 2            OUT049      Medium               Tier 1  Supermarket Type1
# 3            OUT010       Small               Tier 3      Grocery Store
# 4            OUT013        High               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales  Item_Weight_interpolate  Item_Visibility_interpolate  \
# ...

# %%
#for handling categorical data convert categorical into numerical for ml models

# %%
from sklearn.preprocessing import OrdinalEncoder

data_encoded=data.copy()

cat_cols=data.select_dtypes(include=["object"]).columns

for col in cat_cols:
    oe=OrdinalEncoder()
    data_encoded[col]=oe.fit_transform(data_encoded[[col]])
    print(oe.categories_)
# Out:
# [array(['DR', 'FD', 'NC'], dtype=object)]
# [array(['LF', 'Regular'], dtype=object)]
# [array(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others', 'Seafood',
#        'Snack Foods', 'Soft Drinks', 'Starchy Foods'], dtype=object)]
# [array(['OUT010', 'OUT013', 'OUT017', 'OUT018', 'OUT019', 'OUT027',
#        'OUT035', 'OUT045', 'OUT046', 'OUT049'], dtype=object)]
# [array(['High', 'Medium', 'Small'], dtype=object)]
# [array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object)]
# [array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'], dtype=object)]

# %%
data_encoded.head(3)
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Item_MRP  Outlet_Identifier  \
# 0              1.0               0.0        4.0  249.8092                9.0
# 1              0.0               1.0       14.0   48.2692                3.0
# 2              1.0               0.0       10.0  141.6180                9.0
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# 0          1.0                   0.0          1.0          3735.1380
# 1          1.0                   2.0          2.0           443.4228
# 2          1.0                   0.0          1.0          2097.2700
#
#    Item_Weight_interpolate  Item_Visibility_interpolate  Age_Outlet
# 0                     9.30                     0.016047          27
# 1                     5.92                     0.019278          17
# 2                    17.50                     0.016760          27

# %%
X=data_encoded.drop("Item_Outlet_Sales",axis=1)
Y=data_encoded["Item_Outlet_Sales"]

# %%
Y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
#random forest regressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

rf=RandomForestRegressor(n_estimators=100,random_state=42)
scores=cross_val_score(rf,X,Y,cv=5,scoring="r2")
print(scores.mean())
# Out:
# 0.5549938762817801

# %%
# %pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBRFRegressor

xg = XGBRFRegressor(n_estimators=100,random_state=42)
scores = cross_val_score(xg,X,Y,cv=5,scoring='r2')
print(scores.mean())
# Out:
# 0.5954132885089319

# %%
xg = XGBRFRegressor(n_estimators=100,random_state=42)

xg1 = xg.fit(X,Y)
pd.DataFrame({
    'feature':X.columns,
    'XGBRF_importance':xg1.feature_importances_
    
}).sort_values(by='XGBRF_importance',ascending=False)
# Out:
#                         feature  XGBRF_importance
# 7                   Outlet_Type          0.441509
# 10                   Age_Outlet          0.185306
# 3                      Item_MRP          0.155822
# 4             Outlet_Identifier          0.103261
# 5                   Outlet_Size          0.085488
# 6          Outlet_Location_Type          0.019144
# 9   Item_Visibility_interpolate          0.003118
# 8       Item_Weight_interpolate          0.002508
# 2                     Item_Type          0.002053
# 1              Item_Fat_Content          0.001024
# 0               Item_Identifier          0.000767

# %%
final_data = X.drop(columns=[
    'Item_Visibility_interpolate',
    'Item_Weight_interpolate',
    'Item_Type',
    'Outlet_Location_Type',
    'Item_Identifier',
    'Item_Fat_Content'
], errors='ignore')

# %%
final_data = X.drop(columns=['Item_Visibility_interpolate','Item_Weight_interpolate',
'Item_Type','Outlet_Location_Type','Item_Identifier','Item_Fat_Content'],axis=1)

# %%
final_data.sample(2)
# Out:
#       Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Type  Age_Outlet
# 333   230.9984                5.0          1.0          3.0          41
# 3669   76.3328                2.0          2.0          1.0          19

# %%
from xgboost import XGBRFRegressor

# %%
xg_final = XGBRFRegressor()
xg_final.fit(final_data,Y)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, feature_weights=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, ...)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
X_train,X_test,y_train,y_test = train_test_split(final_data,Y,
                                                 test_size=0.20,
                                                 random_state=42)

# %%
xg_final.fit(X_train,y_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, feature_weights=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, ...)

# %%
y_pred = xg_final.predict(X_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 713.7121795633535

# %%
pred = xg_final.predict(np.array([[141.6180,9.0,1.0,1.0,24]]))[0]   #for random input
print(pred)
# Out:
# 2065.1816

# %%
print(f"Sales Value is between {pred-714.42} and {pred+714.42}")
# Out:
# Sales Value is between 1350.761640625 and 2779.601640625

# %%
#saving model

# %%
import joblib
joblib.dump(xg_final,'bigmart_model')
# Out:
# ['bigmart_model']

# %%
model = joblib.load('bigmart_model')

# %%
pred = model.predict(np.array([[141.6180,9.0,1.0,1.0,24]]))[0]
print(pred)
# Out:
# 2065.1816

# %%
print(f"Sales Value is between {pred-714.42} and {pred+714.42}")
# Out:
# Sales Value is between 1350.761640625 and 2779.601640625

# %%
plt.figure(figsize=(8,4))
plt.plot(y_test.values[:50], label="Actual")
plt.plot(y_pred[:50], label="Predicted")
plt.legend()
plt.title("Actual vs Predicted Sales")
plt.xlabel("Samples")
plt.ylabel("Sales")

plt.savefig("sales_prediction_plot.png", bbox_inches="tight")
plt.show()

# %%
import numpy as np
import datetime as dt
from tkinter import *
import joblib
from tkinter import font as tkfont

current_year = dt.datetime.today().year

# ------------------- Prediction Function -------------------
def show_entry_fields():
    try:
        if not e1.get() or not e5.get():
            result_label.config(text="⚠️ Please fill all fields")
            return

        p1 = float(e1.get())

        # Correct encoding (must match training)
        outlet_identifiers = ['OUT010','OUT013','OUT017','OUT018','OUT019',
                              'OUT027','OUT035','OUT045','OUT046','OUT049']
        outlet_sizes = ['High','Medium','Small']
        outlet_types = ['Grocery Store','Supermarket Type1',
                        'Supermarket Type2','Supermarket Type3']

        p2 = outlet_identifiers.index(clicked.get())
        p3 = outlet_sizes.index(clicked0.get())
        p4 = outlet_types.index(clicked1.get())

        p5 = current_year - int(e5.get())

        # Load model (your saved model name)
        model = joblib.load('bigmart_model')

        result = model.predict(np.array([[p1, p2, p3, p4, p5]]))

        result_label.config(
            text=f"💰 Sales between\n{result[0]-714.42:.2f} and {result[0]+714.42:.2f}"
        )

    except ValueError:
        result_label.config(text="⚠️ Enter valid numbers")
    except FileNotFoundError:
        result_label.config(text="⚠️ Model file not found")
    except Exception as e:
        result_label.config(text=f"⚠️ Error: {str(e)}")


# ------------------- UI -------------------
master = Tk()
master.title("Big Mart Sales Prediction")
master.configure(bg='#2c3e50')

# Fonts
title_font = tkfont.Font(size=18, weight="bold")
label_font = tkfont.Font(size=12)
button_font = tkfont.Font(size=14, weight="bold")

# Title
Label(master, text="Big Mart Sales Prediction",
      bg="#2c3e50", fg="white", font=title_font).grid(row=0, columnspan=2, pady=20)

# Labels
labels = ["Item MRP", "Outlet Identifier", "Outlet Size",
          "Outlet Type", "Establishment Year"]

for i, text in enumerate(labels, start=1):
    Label(master, text=text, bg="#2c3e50",
          fg="white", font=label_font).grid(row=i, column=0, padx=10, pady=10)

# Entry
e1 = Entry(master, width=20, font=label_font)
e1.grid(row=1, column=1)

# Dropdowns
options = ['OUT010','OUT013','OUT017','OUT018','OUT019',
           'OUT027','OUT035','OUT045','OUT046','OUT049']
clicked = StringVar()
clicked.set(options[0])
OptionMenu(master, clicked, *options).grid(row=2, column=1)

options0 = ['High','Medium','Small']
clicked0 = StringVar()
clicked0.set(options0[0])
OptionMenu(master, clicked0, *options0).grid(row=3, column=1)

options1 = ['Grocery Store','Supermarket Type1',
            'Supermarket Type2','Supermarket Type3']
clicked1 = StringVar()
clicked1.set(options1[0])
OptionMenu(master, clicked1, *options1).grid(row=4, column=1)

# Year input
e5 = Entry(master, width=20, font=label_font)
e5.grid(row=5, column=1)

# Button
Button(master, text="Predict", command=show_entry_fields,
       bg="#e74c3c", fg="white", font=button_font).grid(row=6, columnspan=2, pady=20)

# Result
result_label = Label(master, text="", bg="#2c3e50",
                     fg="white", font=label_font)
result_label.grid(row=7, columnspan=2)

master.minsize(400, 500)
mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 106
#     103 result_label.grid(row=7, columnspan=2)
#     105 master.minsize(400, 500)
# --> 106 mainloop()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:650, in mainloop(n)
#     648 def mainloop(n=0):
#     649     """Run the main loop of Tcl."""
# --> 650     _get_default_root('run the main loop').tk.mainloop(n)
#
# KeyboardInterrupt:
